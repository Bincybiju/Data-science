# %%
from bs4 import BeautifulSoup
import csv
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
webpage=requests.get("https://www.flipkart.com/search?q=mobiles&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&as-pos=1&as-type=TRENDING&suggestionId=mobiles&requestId=2f07f68b-64d8-4646-87bd-8809d868283b")

# %%
webpage
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(webpage.content,"html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.104e9a.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
# ...

# %%
products=soup.find_all('div',class_='_4rR01T')

# %%
products
# Out:
# [<div class="_4rR01T">OPPO K10 (Blue Flame, 128 GB)</div>,
#  <div class="_4rR01T">OPPO K10 (Black Carbon, 128 GB)</div>,
#  <div class="_4rR01T">MOTOROLA e40 (Carbon Gray, 64 GB)</div>,
#  <div class="_4rR01T">MOTOROLA e40 (Pink Clay, 64 GB)</div>,
#  <div class="_4rR01T">POCO C31 (Royal Blue, 64 GB)</div>,
#  <div class="_4rR01T">Infinix HOT 12 Play (Champagne Gold, 64 GB)</div>,
#  <div class="_4rR01T">vivo T1 44W (Ice Dawn, 128 GB)</div>,
#  <div class="_4rR01T">vivo T1 44W (Starry Sky, 128 GB)</div>,
#  <div class="_4rR01T">MOTOROLA G60 (Moonless, 128 GB)</div>,
#  <div class="_4rR01T">Infinix Note 12 (Jewel Blue, 64 GB)</div>,
#  <div class="_4rR01T">REDMI 9 Activ (Carbon Black, 64 GB)</div>,
#  <div class="_4rR01T">Nokia 105 SS</div>,
#  <div class="_4rR01T">Nokia 105 SS</div>,
#  <div class="_4rR01T">Infinix HOT 12 Play (Daylight Green, 64 GB)</div>,
#  <div class="_4rR01T">Infinix HOT 12 Play (Horizon Blue, 64 GB)</div>,
# ...

# %%
pname=[]
for i in range(0,10):
    pname.append(products[i].get_text())

# %%
pname
# Out:
# ['OPPO K10 (Blue Flame, 128 GB)',
#  'OPPO K10 (Black Carbon, 128 GB)',
#  'MOTOROLA e40 (Carbon Gray, 64 GB)',
#  'MOTOROLA e40 (Pink Clay, 64 GB)',
#  'POCO C31 (Royal Blue, 64 GB)',
#  'Infinix HOT 12 Play (Champagne Gold, 64 GB)',
#  'vivo T1 44W (Ice Dawn, 128 GB)',
#  'vivo T1 44W (Starry Sky, 128 GB)',
#  'MOTOROLA G60 (Moonless, 128 GB)',
#  'Infinix Note 12 (Jewel Blue, 64 GB)']

# %%
price=soup.find_all('div',class_='_30jeq3 _1_WHN1')

# %%
price
# Out:
# [<div class="_30jeq3 _1_WHN1">₹14,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,599</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,599</div>,
#  <div class="_30jeq3 _1_WHN1">₹9,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹9,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,331</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,599</div>,
#  <div class="_30jeq3 _1_WHN1">₹1,299</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹15,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹15,999</div>,
# ...

# %%
pprice=[]
for i in range(0,10):
   pprice.append(price[i].get_text())

# %%
pprice
# Out:
# ['₹14,990',
#  '₹14,990',
#  '₹8,599',
#  '₹8,599',
#  '₹9,499',
#  '₹8,499',
#  '₹14,499',
#  '₹14,499',
#  '₹14,999',
#  '₹9,999']

# %%
rating=soup.find_all('div',class_='_3LWZlK')

# %%
rating
# Out:
# [<div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
# ...

# %%
rate=[]
for i in range(0,10):
    rate.append(rating[i].get_text())

# %%
rate
# Out:
# ['4.4', '4.4', '4.1', '4.1', '4.3', '4.3', '4.4', '4.4', '4.2', '4.2']

# %%
import pandas as pd

# %%
df=pd.DataFrame()

# %%
final=pd.DataFrame({"Mobile-name":pname,"price":pprice,"rating":rate})

# %%
final
# Out:
#                                    Mobile-name    price rating
# 0                OPPO K10 (Blue Flame, 128 GB)  ₹14,990    4.4
# 1              OPPO K10 (Black Carbon, 128 GB)  ₹14,990    4.4
# 2            MOTOROLA e40 (Carbon Gray, 64 GB)   ₹8,599    4.1
# 3              MOTOROLA e40 (Pink Clay, 64 GB)   ₹8,599    4.1
# 4                 POCO C31 (Royal Blue, 64 GB)   ₹9,499    4.3
# 5  Infinix HOT 12 Play (Champagne Gold, 64 GB)   ₹8,499    4.3
# 6               vivo T1 44W (Ice Dawn, 128 GB)  ₹14,499    4.4
# 7             vivo T1 44W (Starry Sky, 128 GB)  ₹14,499    4.4
# 8              MOTOROLA G60 (Moonless, 128 GB)  ₹14,999    4.2
# 9          Infinix Note 12 (Jewel Blue, 64 GB)   ₹9,999    4.2

# %%
final.to_csv("bincy.csv")
